# %%
import cv2
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
flat_chess= cv2.imread("D:\Empty_flat_chess.jpg")
#flat_chess= cv2.cvtColor(flat_chess,cv2.COLOR_BGR2RGB)
plt.imshow(flat_chess)

# %%
found, corners = cv2.findChessboardCorners(flat_chess, (7,7))  # (4,4)

# %%
found # return true if we found corners else return false
# Out:
# True

# %%
#corners  # list of coordinates of the corners

# %%
cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
# Out:
# array([[[186, 215, 242],
#         [187, 217, 244],
#         [180, 213, 239],
#         ...,
#         [ 68, 107, 199],
#         [ 83, 117, 210],
#         [ 18,  40, 135]],
#
#        [[186, 215, 242],
#         [189, 219, 246],
#         [180, 213, 239],
#         ...,
#         [ 61, 100, 192],
#         [ 63,  97, 190],
#         [  6,  31, 125]],
#
#        [[182, 212, 239],
#         [188, 218, 245],
#         [182, 214, 243],
#         ...,
#         [ 60,  99, 191],
#         [ 68, 102, 195],
#         [  8,  34, 128]],
#
#        ...,
#
#        [[ 18,  31, 107],
#         [ 19,  32, 110],
#         [ 16,  33, 112],
#         ...,
#         [  9,  17,  70],
#         [ 19,  28,  85],
#         [ 26,  34, 101]],
#
#        [[ 27,  31, 109],
#         [ 28,  33, 112],
#         [ 26,  33, 113],
#         ...,
#         [ 14,  18,  77],
#         [ 30,  32,  96],
#         [ 27,  32, 101]],
#
#        [[ 38,  34, 110],
#         [ 34,  31, 110],
#         [ 36,  34, 116],
# ...

# %%
plt.imshow(flat_chess)

# %%
dots= cv2.imread("D:\Dot_Grid.jpg")

# %%
plt.imshow(dots)

# %%
found, corners = cv2.findCirclesGrid(dots,(10,10), cv2.CALIB_CB_ASYMMETRIC_GRID )

# %%
found
# Out:
# True

# %%
corners
# Out:
# array([[[ 23.175213,  23.181288]],
#
#        [[ 70.59684 ,  23.191132]],
#
#        [[117.99768 ,  23.16845 ]],
#
#        [[165.38477 ,  23.188662]],
#
#        [[212.82018 ,  23.186758]],
#
#        [[260.1823  ,  23.176737]],
#
#        [[307.61234 ,  23.186604]],
#
#        [[355.00723 ,  23.16701 ]],
#
#        [[402.38635 ,  23.187342]],
#
#        [[449.81558 ,  23.190016]],
#
#        [[ 23.186354,  70.59205 ]],
#
#        [[ 70.60904 ,  70.59578 ]],
#
#        [[118.00139 ,  70.62058 ]],
#
#        [[165.38235 ,  70.60425 ]],
#
#        [[212.83257 ,  70.601944]],
#
#        [[260.20395 ,  70.60546 ]],
#
#        [[307.60873 ,  70.60872 ]],
#
#        [[354.99966 ,  70.59292 ]],
#
#        [[402.40387 ,  70.60706 ]],
#
#        [[449.82465 ,  70.587746]],
#
#        [[ 23.1844  , 117.9909  ]],
#
#        [[ 70.626114, 117.98705 ]],
#
#        [[118.01962 , 118.010765]],
#
#        [[165.41608 , 118.00624 ]],
#
#        [[212.83229 , 117.9976  ]],
#
# ...

# %%
cv2.drawChessboardCorners(dots,(10,10),corners,found)
# Out:
# array([[[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        ...,
#
#        [[254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254],
#         ...,
#         [254, 254, 254],
#         [254, 254, 254],
#         [254, 254, 254]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...

# %%
plt.imshow(dots)

# %% [markdown]
# # To Detect Grid :
#     1st way :
#         found, corners = cv2.findChessboardCorners(img,(7,7)) --> found returns True that the function works well
#                                                               --> corners returns all corners coordinates
#         then:
#             Pass found and corners to --> cv2.drawChessboardCorners(flat_chess,(7,7),corners,found)
#
#     2nd way :
#         found, corners = cv2.findCirclesGrid(dots,(10,10), cv2.CALIB_CB_ASYMMETRIC_GRID ) --> circle grid and use cv2.CALIB_CB_ASYMMETRIC_GRID
#
#         then :
#             Pass found and corners to --> cv2.drawChessboardCorners(dots,(10,10),corners,found)
